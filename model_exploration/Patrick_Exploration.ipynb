# %% [markdown]
# ### Changing the World with Airbnb  - Data Exploration
# #### Patrick Huston | Spring 2016
#
# This notebook aims to explore the dataset made public by Airbnb - a dataset that includes listings, reviews, and calendars of listing availabilities for a whole host of major world cities. In this exploration, I'll be looking mostly at the SF and Boston datasets.

# %% [markdown]
# #### Thoughts for Exploration and CTW Aspect
#
# ##### Questions we would like to tackle
#  - What is the one amenity that makes your listing more desireable? (**Patrick**)
#      - number of reviews vs. number of amenities
#      - review score value accuracy, communication - for different amenities offered
#      - reviewed value
#  - Reviews per month --> host statistics potential analysis - communication score and Review per month
#  - How much does a neighborhood affect the listing's qualities (**Filippos**)
#      - bar graphs based on variation of price
#  - What affects price? (**BOTH --> think about future*
#      - Seasonality
#      - Location (neighborhood, [lat,long])
#      - Bio
#      - Reviews (their sentiments/scores)
#  - Reviews ~ Price ?
#  - Get heatmap of prices and see whether we can detect if there is an affluence (**BOTH**)
#  - Heatmap of desireability of location/area --> Let's look into that later
#  - Time Series of bookings and how many bookings there are for different areas
#  - Acceptance rate --> how does this affect their profile/ratings + host reliability  (**Filippos**)
#  - How does price vary over time (calendar.csv)? Notice any patterns there for different listings? Might have to correlate with the other listings CSV file and derive certain conclusions.
#      - normalize variation in price to see how it is affected by time (calendar.csv)
#  - What gives us a job at Airbnb? (**BOTH**)
#
#
# ##### Vizualizations
#  - Figure out library to use
#      - Seaborn --> use for static/non-static **non-map** vizualizations
#      - JS libraries for overlaying information on maps and other cool stuff - D3
#  - Interactive vs. static
#       - Plotly:
#           - Not enought reference documentation
#           - WebAPI with wrappers - Is it easy to manipulate
#       - Seaborn:
#           - Seems very static-based
#       - Basemap
#           - Nothing super interesting about it
#
# ##### Area/Neighbohood information --> Meta data for the location and context
#  - Perhaps use information from other datasets to *assess* the area
#
# ##### For next time
#  - Explore the dataset and produce insights and vizualizations on the questions we found interesting to tackle
#
# ##### During Tuesday
#  - Develop an API for methods to use
#  - Util for reviews --> poll a given if to get all reviews
#
# ##### Due Friday
#  - Model Iteration #1 and formally present findings on

# %% [markdown]
# #### Imports

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import seaborn as sns

from decimal import Decimal
# Out:
# /home/patrick/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# #### Loading the Data
#
# The data is available publically on [Airbnb's website](http://insideairbnb.com/get-the-data.html) as a csv.

# %%
listingsBoston = pd.read_csv('./data/listingsBoston.csv')
listingsSF = pd.read_csv('./data/listingsSF.csv')
listingsLA = pd.read_csv('./data/listingsLA.csv')
listingsDC = pd.read_csv('./data/listingsDC.csv')
listingsSeattle = pd.read_csv('./data/listingsSeattle.csv')

frames = [listingsBoston, listingsSF, listingsLA, listingsDC, listingsSeattle]

listings = pd.concat(frames)

# listings = listings.dropna(subset=['weekly_price'])
# Out:
# /home/patrick/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
calendarBoston = pd.read_csv('./data/calendarBoston.csv')

calendarBoston = calendarBoston[calendarBoston.available == 't']

# %% [markdown]
# There are tons of features in this dataset - some of them seem like they might be useful, others not as much. To begin with, I'll create a list of the feature names that I intuitively think might be useful/interesting to explore.

# %%
for feature in listings.columns:
    print "- " + feature

features = ['id', 'name', 'summary', 'space', 'neighborhood_overview', 'notes', 
            'transit', 'host_id', 'host_name', 'host_since', 'host_location', 
            'host_about', 'host_response_time', 'host_acceptance_rate', 'host_is_superhost',
            'host_listings_count', 'host_verifications', 'host_has_profile_pic',
            'host_identity_verified', 'street', 'neighbourhood', 'city', 'state', 
            'zipcode', 'market', 'country_code', 'country', 'latitude', 'longitude',
            'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
            'amenities', 'square_feet', 'price', 'weekly_price', 'monthly_price',
            'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
            'minimum_nights', 'maximum_nights', 'calendar_updated', 'has_availability',
            'availability_30', 'availability_60', 'availability_90', 'availability_90',
            'availability_365', 'number_of_reviews', 'first_review', 'last_review',
            'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness',
            'review_scores_communication', 'review_scores_location', 'review_scores_value',
            'cancellation_policy', 'require_guest_profile_picture', 'require_guest_phone_verification',
            'calculated_host_listings_count', 'reviews_per_month']

listings = listings[features]

# listings.describe()
# Out:
# - id
# - name
# - summary
# - space
# - neighborhood_overview
# - notes
# - transit
# - host_id
# - host_name
# - host_since
# - host_location
# - host_about
# - host_response_time
# - host_acceptance_rate
# - host_is_superhost
# - host_listings_count
# - host_verifications
# - host_has_profile_pic
# - host_identity_verified
# - street
# - neighbourhood
# - city
# - state
# - zipcode
# - market
# - country_code
# - country
# - latitude
# - longitude
# - room_type
# - accommodates
# - bathrooms
# - bedrooms
# - beds
# - bed_type
# - amenities
# - square_feet
# - price
# - weekly_price
# - monthly_price
# - security_deposit
# - cleaning_fee
# - guests_included
# - extra_people
# - minimum_nights
# - maximum_nights
# - calendar_updated
# - has_availability
# - availability_30
# - availability_60
# - availability_90
# - availability_90
# - availability_90
# - availability_90
# - availability_365
# - number_of_reviews
# - first_review
# - last_review
# - review_scores_rating
# - review_scores_accuracy
# - review_scores_cleanliness
# - review_scores_communication
# - review_scores_location
# - review_scores_value
# - cancellation_policy
# - require_guest_profile_picture
# - require_guest_phone_verification
# - calculated_host_listings_count
# - reviews_per_month

# %% [markdown]
# #### Data Cleaning
# While we're at it, let's also define a data cleaning function to process the data automatically.

# %%
# Function to parse amenities from str format into list
def amenities_to_list(amenities):
    amenities = amenities.replace('{', '')
    amenities = amenities.replace('}', '')
    amenities = amenities.replace('\"', '')
    return amenities.split(',')

# Get number of amenities
def num_amenities(amenitiesList):
    return len(amenitiesList)

# Turn string dollars into decimals
def price_to_int(price):
    price = price.replace(',', '')
    price = price.replace('$', '')
    return float(price)

# Applies all cleaning functions
def clean_listings(df):
    df_clean = df.copy()
    df_clean['amenities'] = df_clean['amenities'].apply(amenities_to_list)
    df_clean['num_amenities'] = df_clean['amenities'].apply(num_amenities)
    df_clean['price'] = df_clean['price'].apply(price_to_int)
    
    df_clean.loc[df_clean.review_scores_rating.isnull(), 'review_scores_rating'] = 90

    return df_clean

def clean_calendar(df):
    df_clean = df.copy()
    df_clean['price'] = df_clean['price'].apply(price_to_int)

    return df_clean

# %%
listingsClean = clean_listings(listings)

print listingsClean['price'][0]

print listingsClean['amenities'][0]
print listingsClean['num_amenities'][0]
# Out:
# 0     62
# 0    350
# 0    150
# 0    160
# 0     85
# Name: price, dtype: float64
# 0    [TV, Cable TV, Internet, Wireless Internet, Ai...
# 0    [TV, Cable TV, Internet, Wireless Internet, Ki...
# 0    [Cable TV, Wireless Internet, Kitchen, Pets li...
# 0    [TV, Wireless Internet, Air Conditioning, Kitc...
# 0    [TV, Cable TV, Internet, Wireless Internet, Ai...
# Name: amenities, dtype: object
# 0    17
# 0     9
# 0     7
# 0    14
# 0    10
# Name: num_amenities, dtype: int64

# %%
calendarClean = clean_calendar(calendarBoston)

# %% [markdown]
# Now that we have all of the more interesting features in one dataframe, let's get a sense for how the data is distributed. Immediately, it becomes clear that there's not much data available - if our final goal is to produce some predictive model, we're going to want much more than 2558 listings. For now, we'll stick with this, but that's something to keep in mind. Another interesting facet of the data is how high reviews are. I'm wondering if Airbnb inflates ratings or whether all Airbnb listings are really this good - in either case, it is in Airbnb's best interest for ratings to be higher, as people will be more likely to use the service.

# %%
listingsClean.describe()
# Out:
#                     id          host_id  host_listings_count      latitude  \
# count     37690.000000     37690.000000         37683.000000  37690.000000
# mean    5375879.803104  16206661.592306             7.595096     37.163478
# std     2978103.687812  14738506.127815            38.812362      4.309421
# min         109.000000        42.000000             1.000000     33.705835
# 25%     2823531.750000   3551340.750000             1.000000     34.060379
# 50%     5772956.500000  10979943.000000             1.000000     34.157119
# 75%     7937694.500000  26805642.500000             3.000000     38.897171
# max    10340165.000000  53208610.000000           847.000000     47.733358
#
#           longitude  accommodates     bathrooms      bedrooms          beds  \
# count  37690.000000  37690.000000  37423.000000  37606.000000  37599.000000
# mean    -112.223178      3.207535      1.302969      1.294421      1.718024
# std       16.956106      2.138053      0.701128      0.886966      1.287541
# min     -122.513065      1.000000      0.000000      0.000000      0.000000
# 25%     -122.320423      2.000000      1.000000      1.000000      1.000000
# 50%     -118.385000      2.000000      1.000000      1.000000      1.000000
# 75%     -118.245183      4.000000      1.500000      1.000000      2.000000
# max      -70.987107     16.000000      8.000000     10.000000     16.000000
#
#        square_feet      ...        number_of_reviews  review_scores_rating  \
# count   939.000000      ...             37690.000000          37690.000000
# mean    967.680511      ...                16.514036             72.947015
# std     891.504777      ...                30.917784             36.824510
# min       0.000000      ...                 0.000000             10.000000
# 25%     400.000000      ...                 1.000000             40.000000
# 50%     800.000000      ...                 4.000000             93.000000
# 75%    1200.000000      ...                18.000000             98.000000
# max    7000.000000      ...               474.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count            28212.000000               28261.000000
# mean                 9.544804                   9.355048
# std                  0.832597                   1.005918
# min                  2.000000                   2.000000
# 25%                  9.000000                   9.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_communication  review_scores_location  \
# count                 28288.000000            28237.000000
# mean                      9.736531                9.485816
# std                       0.678945                0.825546
# min                       2.000000                2.000000
# 25%                      10.000000                9.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  calculated_host_listings_count  reviews_per_month  \
# count         28235.000000                    37690.000000       28770.000000
# mean              9.329201                        2.865402           1.783400
# std               0.878604                        5.609324           1.734202
# min               2.000000                        1.000000           0.010000
# 25%               9.000000                        1.000000           0.530000
# 50%               9.000000                        1.000000           1.140000
# 75%              10.000000                        2.000000           2.500000
# max              10.000000                       70.000000          13.870000
#
#        num_amenities
# count   37690.000000
# mean       13.934067
# std         5.002276
# min         1.000000
# 25%        11.000000
# 50%        14.000000
# 75%        17.000000
# max        35.000000
#
# [8 rows x 29 columns]

# %%
def plot_distribution(df, col):
    plt.figure(figsize=(12,6))
    sns.set_context("talk")
    sns.distplot(df[col])
    
    sns.plt.title('Distribution of {}'.format(col))
    sns.plt.xlabel('{}'.format(col))
    sns.plt.ylabel('Count')
    
    sns.plt.show()

# %%
plot_distribution(listingsClean, 'num_amenities')

# %%
plot_distribution(listingsClean, 'review_scores_rating')

# %%
bad = listingsClean[listingsClean['review_scores_rating'] < 50]

print bad
# Out:
#             id                                 name  \
# 20     3420384       Convient, Safe and Comfortable
# 21     8473851   Private Room in Single Family Home
# 31     7858329         Charming abode in Roslindale
# 51     7929693      Excellent Room in Jamiaca Plain
# 61     8354938  Egleston Sq JP luxury 2bd w/parking
# 62     1301500   Cozy guest room in the heart of JP
# 68     5904596        Trendy JP Condo, Steps from T
# 72     6862594  Beautiful Home in Jamaica Plain, MA
# 82     8336364               Beautiful Modern Condo
# 87     6386351  Charming Arboretum Area 1+ Bed/1 Ba
# 106    8481291           Beautiful, airy room in JP
# 128    7790454                      Vacation Rental
# 129    8310894              1 Bedroom Jamaica Plain
# 143    2828426   Sunny Apartment in the Heart of JP
# 147    7602111         Pondside Condo- monthly only
# 156    7554801   Cozy guest room. Awesome location!
# 160    5450017  Cosy nook getaway in JP close to T
# 167    6298216  Fun Location, Beautiful & Spacious!
# 170    6436748   Jamaica Plain Cool: City of Boston
# 172    4348422               Cozy Jamaica Plain Pad
# 174    8615156       Modern Room with Private Patio
# 202    5702292                 Elegant Space in JP!
# 222    7742509  Large furnished room hardwood floor
# 228    8226982  Quiet and spacious, right next to T
# 232    8634599  Elegant suite in historic victorian
# 259    8390885  Chic 2 Bedroom Penthouse Loft - NEW
# 262    8673298  Cozy independent room in quiet apt.
# 264    5601743     Beautiful, Expansive Space in JP
# 266    8272350            Bedroom in Jamaica Plain!
# 269    7879708  Sunny, Cozy and Convenient JP Home!
# ...        ...                                  ...
# 3635  10019082  Spacious 1BR Capitol Hill Apartment
# 3637   9618016  Classic Home, Mid-City Neighborhood
# 3650   5059981  Seattle Seahawks vs Packers Weekend
# 3662   7743727  Cozy studio, great Fremont location
# 3668   6867053  Wallingmont Apartment with Balcony!
# 3669   9693230   Cozy home in the center of it all!
# 3671   6392029     Urban cozy apartment in Fremont.
# 3675   8699046    Primely Located Fremont Apartment
# 3677   6169489                         Casa de Chet
# 3685  10060674              In the heart of Fremont
# 3686   9822848            Private room in 2 bed apt
# 3690   9925458        Fremont guest room with futon
# 3706   9513636  Modern&Upscale-walk to GOOGL &Adobe
# 3709   8080939               Fremont View apartment
# 3717   7761509   420-Lovin' Loft, Skyline View+Yard
# 3720   9189391   Sweet and Cozy 1 Bedroom Apartment
# 3722   5902452    Wallingford warmth, perfect loc.!
# 3730   8118110           Cozy Wallingford Apartment
# 3741   8428825   1Br Condo in the Heart of Fremont!
# 3743   3931346                              Frelard
# 3745   6290509     Modern, Sophisticated, 1 Bedroom
# 3766   6043482          1 Room in Beautiful Fremont
# 3780   7009282                     Fremont Bungalow
# 3781   9196007    Luxury Apartment in Artsy Fremont
# 3792   9288840                           City Haven
# 3800   5482204                       Six room suite
# 3802   8562314   Cozy Craftsman in Heart of Fremont
# 3815  10267360    Private apartment view of Lake WA
# 3816   9604740    Amazing View with Modern Comfort!
# 3817  10208623            Large Lakefront Apartment
#
#                                                 summary  \
# 20    Located along public transportation with plent...
# 21    Sunny, smoke free home in a safe and  nice nei...
# 31    Private bedroom comfortable for two travelers,...
# 51    Located just a short walk from the Green St St...
# 61    Luxury private renovated  2 bedroom in prime l...
# 62    I live on the first floor of a quintessential ...
# 68    Lovely 1st-floor, 2 bedroom condo will make yo...
# 72    This is a beautiful space in a gorgeous, newly...
# 82    Refreshingly modern design & hi-end finishes c...
# 87    Beautiful and Charming 1+ Bed/1 Bath apartment...
# 106   Quiet, airy, and clean private room in a nice ...
# 128   My home is a beautiful old victorian condomini...
# 129   This light, spacious unit is in Jamaica Plain,...
# 143   Nestled between the Arnold Arboretum and Centr...
# 147   Spacious pondside apartment in great location ...
# 156   Prime location in Boston (Jamaica Plain), clos...
# 160   You will feel right at home with this hidden G...
# 167   Wonderful & spacious apartment in a fantastic ...
# 170   Two floors in a two-family walking distance of...
# 172   2 bedroom, 2bath, 1200sq ft condo with gorgeou...
# 174   Enjoy a fully furnished private room which com...
# 202   This space is great for travelers looking for ...
# 222   Our large room and queen sized, very comfortab...
# 228   A spacious, well lit room with a large bed. Ov...
# 232   FOR YOUR VISIT TO BOSTON, stay in one of the l...
# 259   Welcome to Jamaica Plain!  This 2 bedroom, 1 b...
# 262   This is a three apartment building, very quiet...
# 264   We are an artist collective who live in a cozy...
# 266   Sunny apartment conveniently located in hip JP...
# 269   Our place is a clean, comfortable, and beautif...
# ...                                                 ...
# 3635  This cozy 1 bedroom, 1 bathroom apartment is l...
# 3637  This welcoming home is in the quiet residentia...
# 3650  Are you looking for a place to stay in Seattle...
# 3662  Great comfortable studio accommodates 2 people...
# 3668  This apartment is in a great area of Seattle, ...
# 3669  Our home is in a highly desirable are near maj...
# 3671  Our one bedroom plus pull out couch sits right...
# 3675  Our 1 bed 1 bath apartment is located in the h...
# 3677                                    Great location.
# 3685  - Fantastic view of the Olympics! (3rd story b...
# 3686  Private clean bedroom with a queen sized bed, ...
# 3690  Perfect for single traveler - plenty of closet...
# 3706  4-story upscale townhouse with rooftop deck an...
# 3709  newly renovated 1904 triplex. Top unit has fan...
# 3717  Welcome! If you crave a local experience with ...
# 3720  This sweet basement apartment is right in betw...
# 3722  Adorable, spacious, & clean home close to dwnt...
# 3730  Our apartment is nestled right in-between the ...
# 3741  Modern, cozy apartment, centrally located in t...
# 3743                        between fremont and ballard
# 3745  This newly designed contemporary apartment sit...
# 3766  I currently share a 2 bedroom apartment with a...
# 3780  Hello and WELCOME! My home is nestled is locat...
# 3781  100% satisfaction from people we host online a...
# 3792  Vacationing in Seattle? Traveling for business...
# 3800         Seattle's most elegant and romantic lit...
# 3802  Our rare for its location, 2 bedroom and 1 bat...
# 3815  Very comfortable lower unit. Quiet, charming m...
# 3816  Cozy studio condo in the heart on Madison Park...
# 3817  All hardwood floors, fireplace, 65" TV with Xb...
#
#                                                   space  \
# 20    Extra large studio with wifi, cable, original ...
# 21    The bedroom is on the second floor of a 2 stor...
# 31    Very comfortable bed! Plenty of shared spaces ...
# 51    Very spacious apartment with pantry, dining ro...
# 61    Located in one of Boston's most ideal location...
# 62    This is a private bedroom in my two bedroom ho...
# 68    Brand new washer and dryer, new garbage dispos...
# 72                                                  NaN
# 82    This newly-built (2014) luxury condo features ...
# 87                                                  NaN
# 106   My apartment is on the top floor of a classic ...
# 128                                                 NaN
# 129                                                 NaN
# 143                                                 NaN
# 147   Beautiful bright and sunny pondside apartment ...
# 156   1870s brownstone in hip JP - Jamaica Plain. Gu...
# 160   You will have access to a newly renovated full...
# 167   Large, open floor plan, a very nice space to r...
# 170   Short walks 5-10 minute walks: To Jamaica Pond...
# 172              Family and dog friendly spacious condo
# 174   The room has direct access to a huge fully fur...
# 202   Available to our guests We have 1 kitchen, 1 f...
# 222   Large room with queen sized bed ample floor sp...
# 228                                                 NaN
# 232   Tall ceilings, glorious sun from south, sunset...
# 259   The space is open and airy with a  true loft f...
# 262                                                 NaN
# 264   Our home is also our office and studio space f...
# 266                                                 NaN
# 269                                                 NaN
# ...                                                 ...
# 3635  THE SPACE:  This spacious but cozy 1 bed, 1 ba...
# 3637  Looking for a comfortable and spacious home fo...
# 3650  Are you looking for a place to stay in Seattle...
# 3662                                                NaN
# 3668                                                NaN
# 3669                                                NaN
# 3671  Easy access to downtown, Fremont, Wallingford,...
# 3675                                                NaN
# 3677                                                NaN
# 3685  My room is about a 12x12 with a full side fram...
# 3686                                                NaN
# 3690                                                NaN
# 3706  Upscale, modern townhome built in 2015 with pl...
# 3709                                                NaN
# 3717  Are you ready for the Seattle experience? If y...
# 3720                                                NaN
# 3722  This home has so much to offer...from the fron...
# 3730  The place is cozy and equipped with everything...
# 3741  This 1 bedroom/1 bathroom condo is the perfect...
# 3743                                                NaN
# 3745  Luxurious and all new apartment in one of Seat...
# 3766  Since the apartment is located in Fremont, fac...
# 3780  Throughout the weekdays, my personal assistant...
# 3781  I've just started offering this space, so you ...
# 3792                                                NaN
# 3800  Each suite is 900 square feet of luxury and el...
# 3802  In a land ruled by condos, it's hard to find a...
# 3815                                                NaN
# 3816  Fully furnished unit to accommodate most needs...
# 3817                                                NaN
#
#                                   neighborhood_overview  \
# 20    Village 1 mile with banks, grocery store, spec...
# 21    Neighborhood is welcoming, close to restaurant...
# 31    Great restaurants, beautiful arboretum, T acce...
# 51    Quiet part of JP, Short walk to Centre St attr...
# 61    Once called "The Eden of America" by a visitor...
# 62    My neighborhood is adorable, my apt a 2 min wa...
# 68    EXTREMELY safe and 2-min walking distance to F...
# 72                                                  NaN
# 82    The unit is a 5 minute walk away from the shop...
# 87                                                  NaN
# 106   My apartment is on the quieter end of Jamaica ...
# 128                                                 NaN
# 129                                                 NaN
# 143   JP is a diverse, vibrant community with tons o...
# 147                                                 NaN
# 156   Not on a main street, but half a block from co...
# 160   Its a great location, with easy access to the ...
# 167                                                 NaN
# 170                                                 NaN
# 172            Great blend of urban fun and green space
# 174   The neighborhood has cute cafes, shops, and re...
# 202   Our neighborhood has a lovely eclectic vibe! I...
# 222   The neighborhood has many restaurants and cafe...
# 228                                                 NaN
# 232   We are on the top of historic Sumner Hill, a p...
# 259   Amazing Neighborhood! Great Cafes, Restaurants...
# 262                                                 NaN
# 264   Our neighborhood has a lovely eclectic vibe! I...
# 266                                                 NaN
# 269                                                 NaN
# ...                                                 ...
# 3635                                                NaN
# 3637  Despite the quiet, leafy streets of this resid...
# 3650  My home is located 6 miles north of Quest Fiel...
# 3662                                                NaN
# 3668                                                NaN
# 3669                                                NaN
# 3671                                                NaN
# 3675                                                NaN
# 3677                                                NaN
# 3685  - Fremont has been called the Center of the Un...
# 3686                                                NaN
# 3690                                                NaN
# 3706                                                NaN
# 3709                                                NaN
# 3717  The neighborhood has a diverse history, which ...
# 3720                                                NaN
# 3722  It's so close to everything...really!  You can...
# 3730  Being nestled between Green Lake, Fremont, and...
# 3741  Nicknamed the "Center of the Universe," Fremon...
# 3743                                                NaN
# 3745  Fremont is one of Seattle's most popular neigh...
# 3766  Fremont is a very eclectic neighborhood with g...
# 3780                                                NaN
# 3781                                                NaN
# 3792                                                NaN
# 3800  Chelsea Station Inn is walking distance to the...
# 3802  I loved living here before we had 3 kids. The ...
# 3815                                                NaN
# 3816  Madison Park offers a peaceful slow pace upsca...
# 3817                                                NaN
#
#                                                   notes  \
# 20    Access to large backyard. Enjoy John's origina...
# 21                                                  NaN
# 31    I have a dog- but can keep her in my room if b...
# 51                                                  NaN
# 61    These are optional : crib, baby stroller, fold...
# 62           I get up early to meditate but I am quiet.
# 68     It's a wonderful place in a great neighborhood.
# 72                                                  NaN
# 82             Condo is approximately 1800 square feet.
# 87                                                  NaN
# 106   You are welcome to use the washer/dryer in the...
# 128                                                 NaN
# 129                                                 NaN
# 143   Please note that there is a king sized bed in ...
# 147                              Minimum one month stay
# 156                                                 NaN
# 160   I want you to feel welcome here during your st...
# 167   There is one queen size bed, one double futon,...
# 170                                                 NaN
# 172                                                 NaN
# 174   The place comes with a free off-street parking...
# 202   As mentioned in our description, we do have ch...
# 222                                                 NaN
# 228                                                 NaN
# 232   Fascinating colonial and civil war era history...
# 259                                                 NaN
# 262                                                 NaN
# 264   As mentioned in our description, we do have ch...
# 266                                                 NaN
# 269                                                 NaN
# ...                                                 ...
# 3635                                                NaN
# 3637                                                NaN
# 3650  The lower level is occupied.  Please respect e...
# 3662                                                NaN
# 3668                                                NaN
# 3669                                                NaN
# 3671                                                NaN
# 3675                                                NaN
# 3677                                                NaN
# 3685  There is one bathroom, which is shared between...
# 3686                                                NaN
# 3690                                                NaN
# 3706  There is absolutely no smoking anywhere on the...
# 3709                                                NaN
# 3717  -Construction to build new homes began 2 weeks...
# 3720                                                NaN
# 3722  I'm expecting to remodel my backyard in the ne...
# 3730                                                NaN
# 3741  This home does come with 2 cats. Both are extr...
# 3743                                                NaN
# 3745  Three night minimum on weekends unless it's a ...
# 3766                                                NaN
# 3780                                                NaN
# 3781                                                NaN
# 3792                                                NaN
# 3800  Each suite's kitchen is coffee ready with Nesp...
# 3802  Please no parties or large groups at our home....
# 3815                                                NaN
# 3816                                                NaN
# 3817               Also our puppy will be boarded away.
#
#                                                 transit   host_id  \
# 20    Airport pick up service. Bus, commuter rail an...    431385
# 21    Located a short walk to bus routes. Parking on...  44625108
# 31                      30 second walk to commuter rail  41413949
# 51    Walk to T, Green St Station, connect to commut...  31760441
# 61    We are a 5 min walk to the Stony Brook Orange ...    206353
# 62    Orange Line, Green Street Stop  Buses (phone n...   3578624
# 68    2-minute walk to Forest Hills T-Stop, so easy ...  24496999
# 72                                                  NaN  10608570
# 82    The Orange Line is a 5 minute walk away, and t...  18807764
# 87                                                  NaN  33289576
# 106   You can use two stations on the Orange Line (S...   8167936
# 128                                                 NaN    869131
# 129                                                 NaN  23916912
# 143   The orange line T station at Green Street is o...   5205634
# 147                                                 NaN  18064808
# 156   Subway - Orange Line - we are in between Stony...  14840087
# 160   Yes the Green T stop is a 5 minute walk. Very ...   1632668
# 167   Six minute walk to the Stony Brook T on the Or...  32750893
# 170   20 minute walk to Green Street Station on the ...  24237839
# 172          5 minutes walk to subway stop and bus stop  22217451
# 174   A five minute walk to the subway station which...  45320497
# 202   We live less than 10 minutes away from the Gre...  19280995
# 222   We are minutes away from both the T and severa...  40695803
# 228                                                 NaN   6703626
# 232   On two T lines -- the Orange Line subway to do...  45402419
# 259   We have parking for 1 car and the loft is loca...  22570468
# 262                                                 NaN  25031795
# 264   We live less than 10 minutes away from the Gre...  19280995
# 266                                                 NaN  37835016
# 269                                                 NaN   7594805
# ...                                                 ...       ...
# 3635                                                NaN  24430641
# 3637  No car? No problem! Multiple bus stops within ...  49761005
# 3650  2 bus locations nearby. One block away and ano...   1566314
# 3662                                                NaN  28139398
# 3668                                                NaN   4193438
# 3669                                                NaN  12901367
# 3671                                                NaN   7719433
# 3675                                                NaN  12832332
# 3677                                                NaN  32008173
# 3685  - There is a bus stop one block away - The pla...  14088426
# 3686                                                NaN  23436894
# 3690                                                NaN  12132989
# 3706                                                NaN  48273510
# 3709                                                NaN  11299221
# 3717  Metro Transit route 5 is one block from the ap...  39845529
# 3720                                                NaN  19628846
# 3722  Absolutely easy!  Very close to bus lines (thr...  30221395
# 3730  As mentioned before, our place is great for wa...   5040711
# 3741  There are several bus stops just around the co...  25904128
# 3743                                                NaN   5062312
# 3745                                                NaN  27189459
# 3766  There is a bus stop 300 ft from the apartment ...   4694909
# 3780  Street parking is available. There are bus rou...  36742703
# 3781                                                NaN   3365488
# 3792                                                NaN  15784748
# 3800                     Super easy by bus or driving !  28432113
# 3802  There is a bus stop on the corner of the stree...  18774473
# 3815                                                NaN  52791370
# 3816                                                Yes  25522052
# 3817                                                NaN  14703116
#
#                 host_name  host_since      ...      review_scores_cleanliness  \
# 20                Cynthia  2011-03-09      ...                            NaN
# 21                Jessica  2015-09-19      ...                            NaN
# 31               Margaret  2015-08-13      ...                            NaN
# 51                   John  2015-04-22      ...                            NaN
# 61                  Perry  2010-08-19      ...                            NaN
# 62                  Karen  2012-09-15      ...                            NaN
# 68                 Justin  2014-12-04      ...                            NaN
# 72                 Edward  2013-12-13      ...                            NaN
# 82                    Dar  2014-07-24      ...                            NaN
# 87                Michael  2015-05-13      ...                            NaN
# 106                  Siqi  2013-08-14      ...                            NaN
# 128                 Maura  2011-07-25      ...                            NaN
# 129                  Zach  2014-11-18      ...                            NaN
# 143                 Paige  2013-02-24      ...                            NaN
# 147             Catherine  2014-07-13      ...                            NaN
# 156                 Carey  2014-04-28      ...                            NaN
# 160                Merlin  2012-01-21      ...                            NaN
# 167                 Jenny  2015-05-06      ...                            NaN
# 170                  Andy  2014-11-27      ...                            NaN
# 172                Ashley  2014-10-06      ...                            NaN
# 174               Mariana  2015-09-28      ...                            NaN
# 202               Kaitlin  2014-08-01      ...                            NaN
# 222             Genevieve  2015-08-06      ...                            NaN
# 228                Isabel  2013-06-02      ...                            NaN
# 232                   Jil  2015-09-29      ...                            NaN
# 259                 Lynne  2014-10-15      ...                            NaN
# 262             Ana Maria  2014-12-20      ...                            NaN
# 264               Kaitlin  2014-08-01      ...                              2
# 266                  Erin  2015-07-07      ...                            NaN
# 269                 Julia  2013-07-19      ...                            NaN
# ...                   ...         ...      ...                            ...
# 3635                David  2014-12-03      ...                            NaN
# 3637                Emily  2015-11-24      ...                            NaN
# 3650               Vienna  2012-01-04      ...                            NaN
# 3662                Robin  2015-02-22      ...                            NaN
# 3668                 Alex  2012-11-19      ...                            NaN
# 3669                Devon  2014-03-07      ...                            NaN
# 3671               Ashton  2013-07-25      ...                            NaN
# 3675                 Kara  2014-03-05      ...                            NaN
# 3677               Amanda  2015-04-26      ...                            NaN
# 3685                Tibor  2014-04-09      ...                            NaN
# 3686               Aniket  2014-11-06      ...                            NaN
# 3690              Christy  2014-02-10      ...                            NaN
# 3706                 Greg  2015-11-05      ...                            NaN
# 3709                Kelly  2014-01-14      ...                            NaN
# 3717              Bethany  2015-07-28      ...                            NaN
# 3720              Chelsea  2014-08-07      ...                            NaN
# 3722              Shannan  2015-03-29      ...                            NaN
# 3730                Steve  2013-02-10      ...                            NaN
# 3741               Lauren  2015-01-10      ...                            NaN
# 3743            Sriharsha  2013-02-12      ...                            NaN
# 3745              Fremont  2015-02-04      ...                            NaN
# 3766                Kevin  2013-01-14      ...                            NaN
# 3780                 Joel  2015-06-25      ...                            NaN
# 3781             Jennifer  2012-08-25      ...                            NaN
# 3792               Teresa  2014-05-20      ...                            NaN
# 3800  Chelsea Station Inn  2015-02-27      ...                            NaN
# 3802             Victoria  2014-07-23      ...                            NaN
# 3815             Virginia  2015-12-30      ...                            NaN
# 3816                Karen  2015-01-03      ...                            NaN
# 3817                  Gil  2014-04-25      ...                            NaN
#
#      review_scores_communication review_scores_location review_scores_value  \
# 20                           NaN                    NaN                 NaN
# 21                           NaN                    NaN                 NaN
# 31                           NaN                    NaN                 NaN
# 51                           NaN                    NaN                 NaN
# 61                           NaN                    NaN                 NaN
# 62                           NaN                    NaN                 NaN
# 68                           NaN                    NaN                 NaN
# 72                           NaN                    NaN                 NaN
# 82                           NaN                    NaN                 NaN
# 87                           NaN                    NaN                 NaN
# 106                          NaN                    NaN                 NaN
# 128                          NaN                    NaN                 NaN
# 129                          NaN                    NaN                 NaN
# 143                          NaN                    NaN                 NaN
# 147                          NaN                    NaN                 NaN
# 156                          NaN                    NaN                 NaN
# 160                          NaN                    NaN                 NaN
# 167                          NaN                    NaN                 NaN
# 170                          NaN                    NaN                 NaN
# 172                          NaN                    NaN                 NaN
# 174                          NaN                    NaN                 NaN
# 202                          NaN                    NaN                 NaN
# 222                          NaN                    NaN                 NaN
# 228                          NaN                    NaN                 NaN
# 232                          NaN                    NaN                 NaN
# 259                          NaN                    NaN                 NaN
# 262                          NaN                    NaN                 NaN
# 264                            2                      2                   2
# 266                          NaN                    NaN                 NaN
# 269                          NaN                    NaN                 NaN
# ...                          ...                    ...                 ...
# 3635                         NaN                    NaN                 NaN
# 3637                         NaN                    NaN                 NaN
# 3650                         NaN                    NaN                 NaN
# 3662                         NaN                    NaN                 NaN
# 3668                         NaN                    NaN                 NaN
# 3669                         NaN                    NaN                 NaN
# 3671                         NaN                    NaN                 NaN
# 3675                         NaN                    NaN                 NaN
# 3677                         NaN                    NaN                 NaN
# 3685                         NaN                    NaN                 NaN
# 3686                         NaN                    NaN                 NaN
# 3690                         NaN                    NaN                 NaN
# 3706                         NaN                    NaN                 NaN
# 3709                         NaN                    NaN                 NaN
# 3717                         NaN                    NaN                 NaN
# 3720                         NaN                    NaN                 NaN
# 3722                         NaN                    NaN                 NaN
# 3730                         NaN                    NaN                 NaN
# 3741                         NaN                    NaN                 NaN
# 3743                         NaN                    NaN                 NaN
# 3745                         NaN                    NaN                 NaN
# 3766                         NaN                    NaN                 NaN
# 3780                         NaN                    NaN                 NaN
# 3781                         NaN                    NaN                 NaN
# 3792                         NaN                    NaN                 NaN
# 3800                         NaN                    NaN                 NaN
# 3802                         NaN                    NaN                 NaN
# 3815                         NaN                    NaN                 NaN
# 3816                         NaN                    NaN                 NaN
# 3817                         NaN                    NaN                 NaN
#
#      cancellation_policy  require_guest_profile_picture  \
# 20              flexible                              f
# 21              flexible                              f
# 31              flexible                              f
# 51              flexible                              f
# 61              moderate                              t
# 62                strict                              f
# 68              flexible                              f
# 72              flexible                              f
# 82                strict                              f
# 87              flexible                              f
# 106             moderate                              f
# 128             flexible                              f
# 129             flexible                              f
# 143               strict                              f
# 147               strict                              f
# 156             moderate                              f
# 160             flexible                              f
# 167             flexible                              f
# 170             flexible                              f
# 172             flexible                              f
# 174             flexible                              f
# 202               strict                              f
# 222             moderate                              f
# 228             flexible                              f
# 232             flexible                              f
# 259               strict                              f
# 262             flexible                              f
# 264               strict                              f
# 266             flexible                              f
# 269             flexible                              f
# ...                  ...                            ...
# 3635              strict                              f
# 3637            flexible                              f
# 3650            flexible                              f
# 3662            flexible                              f
# 3668            flexible                              f
# 3669            flexible                              f
# 3671            flexible                              f
# 3675            flexible                              f
# 3677            flexible                              f
# 3685            flexible                              f
# 3686            flexible                              f
# 3690            flexible                              f
# 3706              strict                              f
# 3709              strict                              f
# 3717            flexible                              f
# 3720            flexible                              f
# 3722            moderate                              f
# 3730            moderate                              f
# 3741            moderate                              f
# 3743            flexible                              f
# 3745              strict                              f
# 3766            flexible                              f
# 3780            moderate                              f
# 3781              strict                              t
# 3792            flexible                              f
# 3800              strict                              f
# 3802            flexible                              f
# 3815            moderate                              f
# 3816            moderate                              f
# 3817            flexible                              f
#
#      require_guest_phone_verification calculated_host_listings_count  \
# 20                                  f                              1
# 21                                  f                              1
# 31                                  f                              1
# 51                                  f                              1
# 61                                  t                              2
# 62                                  f                              1
# 68                                  f                              1
# 72                                  f                              1
# 82                                  f                              1
# 87                                  f                              1
# 106                                 f                              1
# 128                                 f                              2
# 129                                 f                              1
# 143                                 f                              1
# 147                                 f                              1
# 156                                 f                              1
# 160                                 f                              1
# 167                                 f                              1
# 170                                 f                              1
# 172                                 f                              1
# 174                                 f                              1
# 202                                 f                              3
# 222                                 f                              1
# 228                                 f                              1
# 232                                 f                              1
# 259                                 f                              1
# 262                                 f                              1
# 264                                 f                              3
# 266                                 f                              1
# 269                                 f                              1
# ...                               ...                            ...
# 3635                                f                              1
# 3637                                f                              1
# 3650                                f                              1
# 3662                                f                              1
# 3668                                f                              1
# 3669                                f                              1
# 3671                                f                              1
# 3675                                f                              1
# 3677                                f                              1
# 3685                                f                              1
# 3686                                f                              1
# 3690                                f                              1
# 3706                                f                              1
# 3709                                f                              1
# 3717                                f                              2
# 3720                                f                              1
# 3722                                f                              1
# 3730                                f                              1
# 3741                                f                              1
# 3743                                f                              1
# 3745                                f                              2
# 3766                                f                              1
# 3780                                f                              1
# 3781                                t                              2
# 3792                                f                              1
# 3800                                f                              1
# 3802                                f                              1
# 3815                                f                              1
# 3816                                f                              1
# 3817                                f                              1
#
#      reviews_per_month num_amenities
# 20                 NaN            16
# 21                 NaN            15
# 31                 NaN             4
# 51                0.75            11
# 61                 NaN            23
# 62                 NaN            17
# 68                 NaN             1
# 72                 NaN            11
# 82                 NaN            15
# 87                 NaN            13
# 106                NaN            14
# 128                NaN            15
# 129                NaN            15
# 143                NaN            11
# 147                NaN            11
# 156                NaN            13
# 160                NaN            12
# 167                NaN            13
# 170                NaN            13
# 172                NaN            12
# 174                NaN            13
# 202                NaN            15
# 222                NaN             9
# 228                NaN            10
# 232                NaN            13
# 259                NaN            16
# 262                NaN             9
# 264               1.00            15
# 266                NaN            17
# 269                NaN            12
# ...                ...           ...
# 3635               NaN            13
# 3637               NaN            20
# 3650               NaN            13
# 3662               NaN             3
# 3668               NaN             9
# 3669               NaN            10
# 3671              0.21            19
# 3675               NaN            13
# 3677               NaN            13
# 3685               NaN            14
# 3686               NaN             9
# 3690               NaN            15
# 3706               NaN            16
# 3709              0.27            13
# 3717               NaN            16
# 3720               NaN            17
# 3722              0.12            19
# 3730               NaN            17
# 3741               NaN            14
# 3743               NaN             4
# 3745               NaN            17
# 3766              0.13             8
# 3780               NaN            15
# 3781               NaN            13
# 3792               NaN            19
# 3800               NaN            16
# 3802               NaN            12
# 3815               NaN            20
# 3816               NaN            11
# 3817               NaN            22
#
# [9455 rows x 68 columns]

# %%
plot_distribution(listingsClean, 'price')

# %%
plot_distribution(listingsClean, 'accommodates')

# %%
# Helper function to make plots investigating correlation between different features
def explore_correlation(df, col1, col2):
    plt.figure(figsize=(10,6))
    sns.set_context("talk")
    
    sns.regplot(df[col1], df[col2])
    
    sns.plt.title('{} vs. {}'.format(col1, col2))
    sns.plt.xlabel(col1)
    sns.plt.ylabel(col2)
    
    sns.plt.show()

# %%
explore_correlation(listingsClean, 'num_amenities', 'price')

# %%
explore_correlation(listingsClean, 'accommodates', 'price')

# %%
explore_correlation(listingsClean, 'beds', 'price')

# %%
explore_correlation(listingsClean, 'review_scores_rating', 'price')

# %%
explore_correlation(listingsClean, 'reviews_per_month', 'price')

# %%
explore_correlation(listingsClean, 'bathrooms', 'price')

# %%
explore_correlation(listingsClean, 'num_amenities', 'review_scores_rating')
